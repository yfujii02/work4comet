# %%
import checkTrj

##############################
# both 5mmT
##############################
checkTrj.setNumBunch(1488)
checkTrj.main("../data/cth64_SS_2_trj.root")
# Out:
# [b'fileId', b'eventId', b'pId', b'trackId', b'parentId', b'numHits', b'pos', b'mom']
# [b'fileId', b'eventId', b'pId', b'trackId', b'pLevel', b'pos', b'mom', b'posF']
# #of trajectories:  766

# %%
##############################
# both 5mmT
##############################
checkTrj.setNumBunch(744)
checkTrj.main("../data/cth64_SS_trj.root")
# Out:
# [b'fileId', b'eventId', b'pId', b'trackId', b'parentId', b'numHits', b'pos', b'mom']
# [b'fileId', b'eventId', b'pId', b'trackId', b'pLevel', b'pos', b'mom', b'posF']
# #of trajectories:  430

# %%
##############################
# scint 5mmT, cheren 10mmT
##############################
checkTrj.setNumBunch(744)
checkTrj.main("../data/cth64_SC_trj.root")
# Out:
# [b'fileId', b'eventId', b'pId', b'trackId', b'parentId', b'numHits', b'pos', b'mom']
# [b'fileId', b'eventId', b'pId', b'trackId', b'pLevel', b'pos', b'mom', b'posF']
# #of trajectories:  404

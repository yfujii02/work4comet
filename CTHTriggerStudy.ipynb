# %%
import CTHSingleHit

#CTHTriggerStudy.main_loop(0,0,9,0.1,'../data/')
CTHSingleHit.main_loop(0,0,2,'../data/')
# Out:
# ********************************
# Scint+Cheren w/  Birks law
# Energy threshold=  0.1  [MeV]
# #of Cherenkov photon threshold=  10
#
# Start of a file
# Event= 0
# Event= 1
# Event= 2
# Event= 3
# End of a file
# 1 / 3
#
# Start of a file
# Event= 0
# Event= 1
# Event= 2
# Event= 3
# End of a file
# 2 / 3
#
# Start of a file
# Event= 0
# Event= 1
# Event= 2
# Event= 3
# End of a file
# 3 / 3
# 192
# [16. 10. 12. 10. 21. 13. 11. 16. 11. 10. 16.  7. 13.  9. 10. 11. 13. 18.
#  14.  8.  9. 19. 15. 12. 18. 14. 10. 13. 15. 14.  8. 17. 11. 10. 12. 12.
#  12.  7. 11. 12. 19.  5. 11. 16. 17. 14.  9. 10. 45. 53. 54. 49. 52. 39.
#  38. 43. 52. 51. 39. 51. 67. 51. 52. 52. 64. 29. 53. 43. 48. 54. 45. 54.
#  57. 47. 53. 36. 47. 58. 49. 45. 55. 54. 47. 56. 45. 45. 41. 42. 53. 51.
#  54. 55. 39. 53. 58. 40. 28. 30. 27. 43. 34. 36. 38. 37. 43. 44. 40. 36.
#  52. 48. 59. 47. 45. 42. 46. 48. 28. 45. 44. 45. 38. 44. 37. 45. 35. 46.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1eb00ff78cf2> in <module>
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined
